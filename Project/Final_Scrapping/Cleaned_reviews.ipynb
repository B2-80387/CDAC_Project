# %%
import pandas as pd
import miceforest as mf

# %%
df=pd.read_csv('flipkart_laptop_review_data.csv')
df
# Out:
#       Product Review ID                 Title  rating  \
# 0                     3             Must buy!     5.0
# 1                     3     Terrific purchase     5.0
# 2                     4  Good quality product     4.0
# 3                     4             Fabulous!     5.0
# 4                     5     Absolute rubbish!     NaN
# ...                 ...                   ...     ...
# 4144                670             Very poor     NaN
# 4145                670             Very poor     NaN
# 4146                670             Hated it!     NaN
# 4147                670             Very poor     NaN
# 4148                670              Horrible     NaN
#
#                                           detail_review  upvote  downvote
# 0     Really usable one and value for money with all...      18         4
# 1     Product is Awesome 😎 🔥But little Heating Probl...      23        11
# 2     I ordered  Macbook Air - 8GB RAM and 512GB Sto...      32        31
# ...

# %%
df.isna().sum()
# Out:
# Product Review ID      0
# Title                  0
# rating               505
# detail_review          0
# upvote                 0
# downvote               0
# dtype: int64

# %%
# Fill NaN values with a constant (e.g., 0) as respective reviews are negative
df.fillna(0, inplace=True)
df
# Out:
#       Product Review ID                 Title  rating  \
# 0                     3             Must buy!     5.0
# 1                     3     Terrific purchase     5.0
# 2                     4  Good quality product     4.0
# 3                     4             Fabulous!     5.0
# 4                     5     Absolute rubbish!     0.0
# ...                 ...                   ...     ...
# 4144                670             Very poor     0.0
# 4145                670             Very poor     0.0
# 4146                670             Hated it!     0.0
# 4147                670             Very poor     0.0
# 4148                670              Horrible     0.0
#
#                                           detail_review  upvote  downvote
# 0     Really usable one and value for money with all...      18         4
# 1     Product is Awesome 😎 🔥But little Heating Probl...      23        11
# 2     I ordered  Macbook Air - 8GB RAM and 512GB Sto...      32        31
# ...

# %%
df.isna().sum()
# Out:
# Product Review ID    0
# Title                0
# rating               0
# detail_review        0
# upvote               0
# downvote             0
# dtype: int64

# %%
df.to_csv('flipkart_laptop_review_cleaned_data.csv',index=False)
