# %%
import pandas as pd

# %%
df = pd.read_csv("flipkart_laptop_data.csv")
df
# Out:
#                                                Product      Price  Rating  \
# 0    ASUS Vivobook 15 Core i5 11th Gen 1135G7 - (8 ...    ₹38,990     4.3
# 1    ASUS Vivobook 14 Core i3 11th Gen 1115G4 - (8 ...    ₹30,990     4.3
# 2    APPLE 2022 MacBook AIR M2 - (8 GB/512 GB SSD/M...  ₹1,17,990     4.7
# 3    APPLE 2022 MacBook Pro M2 - (8 GB/256 GB SSD/M...  ₹1,09,990     4.6
# 4    APPLE 2022 MacBook AIR M2 - (8 GB/512 GB SSD/M...  ₹1,17,990     4.7
# ..                                                 ...        ...     ...
# 833  Lenovo Core i3 10th Gen 1035G1 - (4 GB/1 TB HD...    ₹36,999     3.9
# 834  MSI GF63 Core i5 11th Gen 11260H - (8 GB/512 G...    ₹44,990     4.2
# 835  ASUS ROG Flow X13 (2022) Ryzen 9 Octa Core 690...    ₹94,990     4.0
# 836  MSI GF63 Core i5 11th Gen 11400H - (8 GB/512 G...    ₹49,290     4.4
# 837  DELL Inspiron Core i3 11th Gen i3-1115G4 - (8 ...    ₹64,500     4.4
#
#                                            Description  \
# 0    Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 1    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 2    Apple M2 Processor8 GB Unified Memory RAMMac O...
# 3    Apple M2 Processor8 GB Unified Memory RAMMac O...
# 4    Apple M2 Processor8 GB Unified Memory RAMMac O...
# ..                                                 ...
# 833  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 834  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 835  AMD Ryzen 9 Octa Core Processor16 GB LPDDR5 RA...
# 836  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 837  Active PenIntel Core i3 Processor (11th Gen)8 ...
#
#                                                    Url
# 0    /asus-vivobook-15-core-i5-11th-gen-1135g7-8-gb...
# 1    /asus-vivobook-14-core-i3-11th-gen-1115g4-8-gb...
# 2    /apple-2022-macbook-air-m2-8-gb-512-gb-ssd-mac...
# 3    /apple-2022-macbook-pro-m2-8-gb-256-gb-ssd-mac...
# 4    /apple-2022-macbook-air-m2-8-gb-512-gb-ssd-mac...
# ..                                                 ...
# 833  /lenovo-core-i3-10th-gen-1035g1-4-gb-1-tb-hdd-...
# 834  /msi-gf63-core-i5-11th-gen-11260h-8-gb-512-gb-...
# 835  /asus-rog-flow-x13-2022-ryzen-9-octa-core-6900...
# 836  /msi-gf63-core-i5-11th-gen-11400h-8-gb-512-gb-...
# 837  /dell-inspiron-core-i3-11th-gen-i3-1115g4-8-gb...
#
# [838 rows x 5 columns]

# %%
# Check if data has any NAN values
df.isna().sum()
# Out:
# Product        0
# Price          0
# Rating         0
# Description    0
# Url            0
# Review Url     0
# dtype: int64

# %%
#Check number of uniqueIds to see if there's any duplicate record in our dataset
df['Product'].nunique()
# Out:
# 477

# %%
df['Price'] = df['Price'].str.replace('₹', '')
df['Price'] = df['Price'].str.replace(',', '')
df['Price'] = df['Price'].astype(float)

# %%
# Construct the product-review links from product links
review_urls = []
df['Url'] = 'https://www.flipkart.com' + df['Url']
for link in df['Url']:
    url = link.split('/p/')
    review_link = url[0] + '/product-reviews/' + url[1]
    review_urls.append(review_link)

# %%
df
# Out:
#                                                Product     Price  Rating  \
# 0    ASUS Vivobook 15 Core i5 11th Gen 1135G7 - (8 ...   38990.0     4.3
# 1    ASUS Vivobook 14 Core i3 11th Gen 1115G4 - (8 ...   30990.0     4.3
# 2    APPLE 2022 MacBook AIR M2 - (8 GB/512 GB SSD/M...  117990.0     4.7
# 3    APPLE 2022 MacBook Pro M2 - (8 GB/256 GB SSD/M...  109990.0     4.6
# 4    APPLE 2022 MacBook AIR M2 - (8 GB/512 GB SSD/M...  117990.0     4.7
# ..                                                 ...       ...     ...
# 833  Lenovo Core i3 10th Gen 1035G1 - (4 GB/1 TB HD...   36999.0     3.9
# 834  MSI GF63 Core i5 11th Gen 11260H - (8 GB/512 G...   44990.0     4.2
# 835  ASUS ROG Flow X13 (2022) Ryzen 9 Octa Core 690...   94990.0     4.0
# 836  MSI GF63 Core i5 11th Gen 11400H - (8 GB/512 G...   49290.0     4.4
# 837  DELL Inspiron Core i3 11th Gen i3-1115G4 - (8 ...   64500.0     4.4
#
#                                            Description  \
# 0    Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 1    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 2    Apple M2 Processor8 GB Unified Memory RAMMac O...
# 3    Apple M2 Processor8 GB Unified Memory RAMMac O...
# 4    Apple M2 Processor8 GB Unified Memory RAMMac O...
# ..                                                 ...
# 833  Intel Core i3 Processor (10th Gen)4 GB DDR4 RA...
# 834  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 835  AMD Ryzen 9 Octa Core Processor16 GB LPDDR5 RA...
# 836  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 837  Active PenIntel Core i3 Processor (11th Gen)8 ...
#
#                                                    Url
# 0    https://www.flipkart.com/asus-vivobook-15-core...
# 1    https://www.flipkart.com/asus-vivobook-14-core...
# 2    https://www.flipkart.com/apple-2022-macbook-ai...
# 3    https://www.flipkart.com/apple-2022-macbook-pr...
# 4    https://www.flipkart.com/apple-2022-macbook-ai...
# ..                                                 ...
# 833  https://www.flipkart.com/lenovo-core-i3-10th-g...
# 834  https://www.flipkart.com/msi-gf63-core-i5-11th...
# 835  https://www.flipkart.com/asus-rog-flow-x13-202...
# 836  https://www.flipkart.com/msi-gf63-core-i5-11th...
# 837  https://www.flipkart.com/dell-inspiron-core-i3...
#
# [838 rows x 5 columns]

# %%
# Store the list as column in the DataFrame
df['Review Url'] = review_urls

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 0 to 837
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Product      838 non-null    object
#  1   Price        838 non-null    float64
#  2   Rating       838 non-null    float64
#  3   Description  838 non-null    object
#  4   Url          838 non-null    object
#  5   Review Url   838 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 39.4+ KB
# None

# %%
df.describe()
# Out:
#                Price      Rating
# count     838.000000  838.000000
# mean    59636.548926    4.219212
# std     34133.246784    0.343919
# min     20090.000000    1.000000
# 25%     37990.000000    4.200000
# 50%     49990.000000    4.300000
# 75%     69997.500000    4.400000
# max    309990.000000    5.000000
